# %%
import sys
from matplotlib import pyplot
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.python.client import device_lib
from numba import cuda

# %%
print(device_lib.list_local_devices())
(trainX, trainY), (testX, testY) = cifar10.load_data()
trainY = to_categorical(trainY)
testY = to_categorical(testY)
trainX = trainX.astype('float32')/255.0
testX = testX.astype('float32')/255.0
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14860872126999048358
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6252920832
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1151665403485341294
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 2080 SUPER, pci bus id: 0000:09:00.0, compute capability: 7.5"
# ]

# %%
factor = 4
with tf.device('/device:GPU:0'):
    model = Sequential()
    model.add(Conv2D(32*factor, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
    model.add(BatchNormalization())
    model.add(Conv2D(32*factor, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))
    model.add(Conv2D(64*factor, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(64*factor, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.3))
    model.add(Conv2D(128*factor, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(128*factor, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.4))
    model.add(Flatten())
    model.add(Dense(128*factor, activation='relu', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    opt = SGD(learning_rate=0.001, momentum=0.9)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
it_train = datagen.flow(trainX, trainY, batch_size=64)
steps = (trainX.shape[0] / 64)
model.fit_generator(it_train, steps_per_epoch=steps, epochs=50, validation_data=(testX, testY))
# Out:
# Epoch 1/50
# 781/781 [==============================] - 23s 29ms/step - loss: 1.9822 - accuracy: 0.3630 - val_loss: 1.3913 - val_accuracy: 0.4976
# Epoch 2/50
# 781/781 [==============================] - 22s 28ms/step - loss: 1.4547 - accuracy: 0.4852 - val_loss: 1.3398 - val_accuracy: 0.5209
# Epoch 3/50
# 781/781 [==============================] - 22s 28ms/step - loss: 1.2789 - accuracy: 0.5415 - val_loss: 1.2450 - val_accuracy: 0.5597
# Epoch 4/50
# 781/781 [==============================] - 22s 28ms/step - loss: 1.1539 - accuracy: 0.5868 - val_loss: 1.4279 - val_accuracy: 0.5283
# Epoch 5/50
# 781/781 [==============================] - 22s 28ms/step - loss: 1.0781 - accuracy: 0.6156 - val_loss: 1.2328 - val_accuracy: 0.5839
# Epoch 6/50
# 781/781 [==============================] - 22s 28ms/step - loss: 1.0158 - accuracy: 0.6393 - val_loss: 1.0804 - val_accuracy: 0.6256
# Epoch 7/50
# ...

# %%
# device = cuda.get_current_device()
# device.reset()
model.fit_generator(it_train, steps_per_epoch=steps, epochs=350, validation_data=(testX, testY))
# Out:
# Epoch 1/350
# 781/781 [==============================] - 23s 29ms/step - loss: 0.3967 - accuracy: 0.8623 - val_loss: 0.4527 - val_accuracy: 0.8501
# Epoch 2/350
# 781/781 [==============================] - 22s 29ms/step - loss: 0.3946 - accuracy: 0.8640 - val_loss: 0.4701 - val_accuracy: 0.8465
# Epoch 3/350
# 781/781 [==============================] - 21s 27ms/step - loss: 0.3866 - accuracy: 0.8650 - val_loss: 0.4932 - val_accuracy: 0.8404
# Epoch 4/350
# 781/781 [==============================] - 21s 27ms/step - loss: 0.3838 - accuracy: 0.8658 - val_loss: 0.4822 - val_accuracy: 0.8444
# Epoch 5/350
# 781/781 [==============================] - 22s 29ms/step - loss: 0.3763 - accuracy: 0.8684 - val_loss: 0.4406 - val_accuracy: 0.8572
# Epoch 6/350
# 781/781 [==============================] - 23s 30ms/step - loss: 0.3740 - accuracy: 0.8702 - val_loss: 0.5007 - val_accuracy: 0.8422
# Epoch 7/350
# ...
